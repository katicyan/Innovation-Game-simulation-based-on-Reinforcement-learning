# %%
class animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species

    def make_sound(self) -> str:
        return "Some sound"
class dog(animal):
    def __init__(self, name, breed):
        super().__init__(name, "Dog")
        self.breed = breed

    def make_sound(self) -> str:
        if self.species == "Unknown":
            return super().make_sound()  # Call the parent class method (optional)
        else:
            return "Woof!"


dog1 = dog("Buddy", "Golden Retriever")
print(f"{dog1.name} is a {dog1.species} of breed {dog1.breed}.")
print(f"{dog1.name} says: {dog1.make_sound()}")
# Out:
# Buddy is a Dog of breed Golden Retriever.
# Buddy says: Woof!
